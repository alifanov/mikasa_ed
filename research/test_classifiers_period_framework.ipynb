# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt

import numpy as np

from sklearn.preprocessing import StandardScaler

np.random.seed(7)

# %%
def validate_model(cls_name, model, X_train, y_train, X_test, y_test, period, pair, lag):
    info_format = '{3:.3f}: [period: {0}](lag: {1}): {2} | {4}'
    
    model.fit(X_train, y_train)
    print(info_format.format(period, lag, cls_name, model.score(X_test, y_test), pair))

def test_cls(period, pair, lag):
    df = pd.read_csv('../datasets/{}/{}.csv'.format(period, pair), index_col=0)
    close_lag_fields = ['close-{}'.format(n+1) for n in range(lag)]
    for n in range(1, lag+1):
        df['close-' + str(n)] = df['close'] - df.shift(n)['close']
    df['up'] = df['close'] < df.shift(-1)['close']
    df.dropna(inplace=True)
    X = df[close_lag_fields].values
    y = df['up'].astype(int).values

    scaler = StandardScaler()

    X = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)
    
    model = RandomForestClassifier(n_jobs=4, random_state=0, n_estimators=20)
    validate_model('Random forest', model, X_train, y_train, X_test, y_test, period, pair, lag)
    
    model = SGDClassifier(loss="hinge", penalty="l2")
    validate_model('SGD', model, X_train, y_train, X_test, y_test, period, pair, lag)
    
    model = LogisticRegression()
    validate_model('Logistic regression', model, X_train, y_train, X_test, y_test, period, pair, lag)
    
    model = GradientBoostingClassifier(max_depth=4)
    validate_model('Gradient boosting', model, X_train, y_train, X_test, y_test, period, pair, lag)
    
    model = MLPClassifier()
    validate_model('MLP', model, X_train, y_train, X_test, y_test, period, pair, lag)
    
    model = DecisionTreeClassifier()
    validate_model('Decision tree', model, X_train, y_train, X_test, y_test, period, pair, lag)

    model = KNeighborsClassifier()
    validate_model('KNeighbours', model, X_train, y_train, X_test, y_test, period, pair, lag)

    print()

# %%
for period in ['5min', '30min', 'day']:
    for lag in range(2, 13):
        for pair in ['BTC_ETC', 'BTC_LTC']:
            test_cls(period, pair, lag)
# Out:
# 0.528: [period: 5min](lag: 2): Random forest | BTC_ETC
# 0.544: [period: 5min](lag: 2): SGD | BTC_ETC
# 0.542: [period: 5min](lag: 2): Logistic regression | BTC_ETC
# 0.563: [period: 5min](lag: 2): Gradient boosting | BTC_ETC
# 0.563: [period: 5min](lag: 2): MLP | BTC_ETC
# 0.518: [period: 5min](lag: 2): Decision tree | BTC_ETC
# 0.533: [period: 5min](lag: 2): KNeighbours | BTC_ETC
#
# 0.537: [period: 5min](lag: 2): Random forest | BTC_LTC
# 0.542: [period: 5min](lag: 2): SGD | BTC_LTC
# 0.541: [period: 5min](lag: 2): Logistic regression | BTC_LTC
# 0.575: [period: 5min](lag: 2): Gradient boosting | BTC_LTC
# 0.570: [period: 5min](lag: 2): MLP | BTC_LTC
# 0.526: [period: 5min](lag: 2): Decision tree | BTC_LTC
# 0.539: [period: 5min](lag: 2): KNeighbours | BTC_LTC
#
# 0.541: [period: 5min](lag: 3): Random forest | BTC_ETC
# 0.548: [period: 5min](lag: 3): SGD | BTC_ETC
# 0.548: [period: 5min](lag: 3): Logistic regression | BTC_ETC
# 0.569: [period: 5min](lag: 3): Gradient boosting | BTC_ETC
# 0.567: [period: 5min](lag: 3): MLP | BTC_ETC
# 0.514: [period: 5min](lag: 3): Decision tree | BTC_ETC
# 0.533: [period: 5min](lag: 3): KNeighbours | BTC_ETC
#
# 0.552: [period: 5min](lag: 3): Random forest | BTC_LTC
# 0.541: [period: 5min](lag: 3): SGD | BTC_LTC
# 0.543: [period: 5min](lag: 3): Logistic regression | BTC_LTC
# 0.582: [period: 5min](lag: 3): Gradient boosting | BTC_LTC
# 0.578: [period: 5min](lag: 3): MLP | BTC_LTC
# 0.528: [period: 5min](lag: 3): Decision tree | BTC_LTC
# 0.554: [period: 5min](lag: 3): KNeighbours | BTC_LTC
#
# 0.541: [period: 5min](lag: 4): Random forest | BTC_ETC
# 0.550: [period: 5min](lag: 4): SGD | BTC_ETC
# 0.550: [period: 5min](lag: 4): Logistic regression | BTC_ETC
# 0.571: [period: 5min](lag: 4): Gradient boosting | BTC_ETC
# 0.570: [period: 5min](lag: 4): MLP | BTC_ETC
# 0.521: [period: 5min](lag: 4): Decision tree | BTC_ETC
# 0.532: [period: 5min](lag: 4): KNeighbours | BTC_ETC
#
# 0.560: [period: 5min](lag: 4): Random forest | BTC_LTC
# 0.538: [period: 5min](lag: 4): SGD | BTC_LTC
# 0.541: [period: 5min](lag: 4): Logistic regression | BTC_LTC
# 0.591: [period: 5min](lag: 4): Gradient boosting | BTC_LTC
# 0.583: [period: 5min](lag: 4): MLP | BTC_LTC
# 0.527: [period: 5min](lag: 4): Decision tree | BTC_LTC
# 0.555: [period: 5min](lag: 4): KNeighbours | BTC_LTC
#
# 0.542: [period: 5min](lag: 5): Random forest | BTC_ETC
# 0.549: [period: 5min](lag: 5): SGD | BTC_ETC
# 0.543: [period: 5min](lag: 5): Logistic regression | BTC_ETC
# 0.565: [period: 5min](lag: 5): Gradient boosting | BTC_ETC
# 0.558: [period: 5min](lag: 5): MLP | BTC_ETC
# 0.520: [period: 5min](lag: 5): Decision tree | BTC_ETC
# 0.531: [period: 5min](lag: 5): KNeighbours | BTC_ETC
#
# 0.563: [period: 5min](lag: 5): Random forest | BTC_LTC
# 0.541: [period: 5min](lag: 5): SGD | BTC_LTC
# 0.540: [period: 5min](lag: 5): Logistic regression | BTC_LTC
# 0.580: [period: 5min](lag: 5): Gradient boosting | BTC_LTC
# 0.577: [period: 5min](lag: 5): MLP | BTC_LTC
# 0.530: [period: 5min](lag: 5): Decision tree | BTC_LTC
# 0.553: [period: 5min](lag: 5): KNeighbours | BTC_LTC
#
# 0.545: [period: 5min](lag: 6): Random forest | BTC_ETC
# 0.553: [period: 5min](lag: 6): SGD | BTC_ETC
# 0.551: [period: 5min](lag: 6): Logistic regression | BTC_ETC
# 0.571: [period: 5min](lag: 6): Gradient boosting | BTC_ETC
# 0.570: [period: 5min](lag: 6): MLP | BTC_ETC
# 0.521: [period: 5min](lag: 6): Decision tree | BTC_ETC
# 0.535: [period: 5min](lag: 6): KNeighbours | BTC_ETC
#
# 0.564: [period: 5min](lag: 6): Random forest | BTC_LTC
# 0.539: [period: 5min](lag: 6): SGD | BTC_LTC
# 0.541: [period: 5min](lag: 6): Logistic regression | BTC_LTC
# 0.583: [period: 5min](lag: 6): Gradient boosting | BTC_LTC
# 0.580: [period: 5min](lag: 6): MLP | BTC_LTC
# 0.530: [period: 5min](lag: 6): Decision tree | BTC_LTC
# 0.547: [period: 5min](lag: 6): KNeighbours | BTC_LTC
#
# 0.549: [period: 5min](lag: 7): Random forest | BTC_ETC
# 0.543: [period: 5min](lag: 7): SGD | BTC_ETC
# 0.543: [period: 5min](lag: 7): Logistic regression | BTC_ETC
# 0.573: [period: 5min](lag: 7): Gradient boosting | BTC_ETC
# 0.567: [period: 5min](lag: 7): MLP | BTC_ETC
# 0.515: [period: 5min](lag: 7): Decision tree | BTC_ETC
# 0.540: [period: 5min](lag: 7): KNeighbours | BTC_ETC
#
# 0.568: [period: 5min](lag: 7): Random forest | BTC_LTC
# 0.540: [period: 5min](lag: 7): SGD | BTC_LTC
# 0.540: [period: 5min](lag: 7): Logistic regression | BTC_LTC
# 0.585: [period: 5min](lag: 7): Gradient boosting | BTC_LTC
# 0.581: [period: 5min](lag: 7): MLP | BTC_LTC
# 0.526: [period: 5min](lag: 7): Decision tree | BTC_LTC
# 0.552: [period: 5min](lag: 7): KNeighbours | BTC_LTC
#
# 0.550: [period: 5min](lag: 8): Random forest | BTC_ETC
# 0.552: [period: 5min](lag: 8): SGD | BTC_ETC
# 0.545: [period: 5min](lag: 8): Logistic regression | BTC_ETC
# 0.569: [period: 5min](lag: 8): Gradient boosting | BTC_ETC
# 0.566: [period: 5min](lag: 8): MLP | BTC_ETC
# 0.519: [period: 5min](lag: 8): Decision tree | BTC_ETC
# 0.539: [period: 5min](lag: 8): KNeighbours | BTC_ETC
#
# 0.566: [period: 5min](lag: 8): Random forest | BTC_LTC
# 0.540: [period: 5min](lag: 8): SGD | BTC_LTC
# 0.543: [period: 5min](lag: 8): Logistic regression | BTC_LTC
# 0.580: [period: 5min](lag: 8): Gradient boosting | BTC_LTC
# 0.582: [period: 5min](lag: 8): MLP | BTC_LTC
# 0.535: [period: 5min](lag: 8): Decision tree | BTC_LTC
# 0.548: [period: 5min](lag: 8): KNeighbours | BTC_LTC
#
# 0.557: [period: 5min](lag: 9): Random forest | BTC_ETC
# 0.544: [period: 5min](lag: 9): SGD | BTC_ETC
# 0.541: [period: 5min](lag: 9): Logistic regression | BTC_ETC
# 0.569: [period: 5min](lag: 9): Gradient boosting | BTC_ETC
# 0.564: [period: 5min](lag: 9): MLP | BTC_ETC
# 0.525: [period: 5min](lag: 9): Decision tree | BTC_ETC
# 0.535: [period: 5min](lag: 9): KNeighbours | BTC_ETC
#
# 0.572: [period: 5min](lag: 9): Random forest | BTC_LTC
# 0.537: [period: 5min](lag: 9): SGD | BTC_LTC
# 0.539: [period: 5min](lag: 9): Logistic regression | BTC_LTC
# 0.587: [period: 5min](lag: 9): Gradient boosting | BTC_LTC
# 0.588: [period: 5min](lag: 9): MLP | BTC_LTC
# 0.531: [period: 5min](lag: 9): Decision tree | BTC_LTC
# 0.554: [period: 5min](lag: 9): KNeighbours | BTC_LTC
#
# 0.557: [period: 5min](lag: 10): Random forest | BTC_ETC
# 0.546: [period: 5min](lag: 10): SGD | BTC_ETC
# 0.550: [period: 5min](lag: 10): Logistic regression | BTC_ETC
# 0.576: [period: 5min](lag: 10): Gradient boosting | BTC_ETC
# 0.571: [period: 5min](lag: 10): MLP | BTC_ETC
# 0.522: [period: 5min](lag: 10): Decision tree | BTC_ETC
# 0.539: [period: 5min](lag: 10): KNeighbours | BTC_ETC
#
# 0.566: [period: 5min](lag: 10): Random forest | BTC_LTC
# 0.539: [period: 5min](lag: 10): SGD | BTC_LTC
# 0.541: [period: 5min](lag: 10): Logistic regression | BTC_LTC
# 0.587: [period: 5min](lag: 10): Gradient boosting | BTC_LTC
# 0.586: [period: 5min](lag: 10): MLP | BTC_LTC
# 0.532: [period: 5min](lag: 10): Decision tree | BTC_LTC
# 0.556: [period: 5min](lag: 10): KNeighbours | BTC_LTC
#
# 0.555: [period: 5min](lag: 11): Random forest | BTC_ETC
# 0.549: [period: 5min](lag: 11): SGD | BTC_ETC
# 0.546: [period: 5min](lag: 11): Logistic regression | BTC_ETC
# 0.577: [period: 5min](lag: 11): Gradient boosting | BTC_ETC
# 0.563: [period: 5min](lag: 11): MLP | BTC_ETC
# 0.524: [period: 5min](lag: 11): Decision tree | BTC_ETC
# 0.537: [period: 5min](lag: 11): KNeighbours | BTC_ETC
#
# 0.561: [period: 5min](lag: 11): Random forest | BTC_LTC
# 0.541: [period: 5min](lag: 11): SGD | BTC_LTC
# 0.535: [period: 5min](lag: 11): Logistic regression | BTC_LTC
# 0.586: [period: 5min](lag: 11): Gradient boosting | BTC_LTC
# 0.581: [period: 5min](lag: 11): MLP | BTC_LTC
# 0.533: [period: 5min](lag: 11): Decision tree | BTC_LTC
# 0.556: [period: 5min](lag: 11): KNeighbours | BTC_LTC
#
# 0.551: [period: 5min](lag: 12): Random forest | BTC_ETC
# 0.533: [period: 5min](lag: 12): SGD | BTC_ETC
# 0.547: [period: 5min](lag: 12): Logistic regression | BTC_ETC
# 0.575: [period: 5min](lag: 12): Gradient boosting | BTC_ETC
# 0.573: [period: 5min](lag: 12): MLP | BTC_ETC
# 0.523: [period: 5min](lag: 12): Decision tree | BTC_ETC
# 0.540: [period: 5min](lag: 12): KNeighbours | BTC_ETC
#
# 0.568: [period: 5min](lag: 12): Random forest | BTC_LTC
# 0.535: [period: 5min](lag: 12): SGD | BTC_LTC
# 0.539: [period: 5min](lag: 12): Logistic regression | BTC_LTC
# 0.583: [period: 5min](lag: 12): Gradient boosting | BTC_LTC
# 0.581: [period: 5min](lag: 12): MLP | BTC_LTC
# 0.535: [period: 5min](lag: 12): Decision tree | BTC_LTC
# 0.553: [period: 5min](lag: 12): KNeighbours | BTC_LTC
#
# 0.500: [period: 30min](lag: 2): Random forest | BTC_ETC
# 0.477: [period: 30min](lag: 2): SGD | BTC_ETC
# 0.528: [period: 30min](lag: 2): Logistic regression | BTC_ETC
# 0.533: [period: 30min](lag: 2): Gradient boosting | BTC_ETC
# 0.529: [period: 30min](lag: 2): MLP | BTC_ETC
# 0.498: [period: 30min](lag: 2): Decision tree | BTC_ETC
# 0.507: [period: 30min](lag: 2): KNeighbours | BTC_ETC
#
# 0.534: [period: 30min](lag: 2): Random forest | BTC_LTC
# 0.530: [period: 30min](lag: 2): SGD | BTC_LTC
# 0.529: [period: 30min](lag: 2): Logistic regression | BTC_LTC
# 0.554: [period: 30min](lag: 2): Gradient boosting | BTC_LTC
# 0.561: [period: 30min](lag: 2): MLP | BTC_LTC
# 0.514: [period: 30min](lag: 2): Decision tree | BTC_LTC
# 0.538: [period: 30min](lag: 2): KNeighbours | BTC_LTC
#
# 0.524: [period: 30min](lag: 3): Random forest | BTC_ETC
# 0.536: [period: 30min](lag: 3): SGD | BTC_ETC
# 0.543: [period: 30min](lag: 3): Logistic regression | BTC_ETC
# 0.545: [period: 30min](lag: 3): Gradient boosting | BTC_ETC
# 0.547: [period: 30min](lag: 3): MLP | BTC_ETC
# 0.512: [period: 30min](lag: 3): Decision tree | BTC_ETC
# 0.493: [period: 30min](lag: 3): KNeighbours | BTC_ETC
#
# 0.540: [period: 30min](lag: 3): Random forest | BTC_LTC
# 0.483: [period: 30min](lag: 3): SGD | BTC_LTC
# 0.533: [period: 30min](lag: 3): Logistic regression | BTC_LTC
# 0.568: [period: 30min](lag: 3): Gradient boosting | BTC_LTC
# 0.568: [period: 30min](lag: 3): MLP | BTC_LTC
# 0.515: [period: 30min](lag: 3): Decision tree | BTC_LTC
# 0.546: [period: 30min](lag: 3): KNeighbours | BTC_LTC
#
# 0.505: [period: 30min](lag: 4): Random forest | BTC_ETC
# 0.525: [period: 30min](lag: 4): SGD | BTC_ETC
# 0.535: [period: 30min](lag: 4): Logistic regression | BTC_ETC
# 0.530: [period: 30min](lag: 4): Gradient boosting | BTC_ETC
# 0.538: [period: 30min](lag: 4): MLP | BTC_ETC
# 0.503: [period: 30min](lag: 4): Decision tree | BTC_ETC
# 0.514: [period: 30min](lag: 4): KNeighbours | BTC_ETC
#
# 0.531: [period: 30min](lag: 4): Random forest | BTC_LTC
# 0.527: [period: 30min](lag: 4): SGD | BTC_LTC
# 0.535: [period: 30min](lag: 4): Logistic regression | BTC_LTC
# 0.568: [period: 30min](lag: 4): Gradient boosting | BTC_LTC
# 0.557: [period: 30min](lag: 4): MLP | BTC_LTC
# 0.501: [period: 30min](lag: 4): Decision tree | BTC_LTC
# 0.537: [period: 30min](lag: 4): KNeighbours | BTC_LTC
#
# 0.525: [period: 30min](lag: 5): Random forest | BTC_ETC
# 0.537: [period: 30min](lag: 5): SGD | BTC_ETC
# 0.542: [period: 30min](lag: 5): Logistic regression | BTC_ETC
# 0.537: [period: 30min](lag: 5): Gradient boosting | BTC_ETC
# 0.548: [period: 30min](lag: 5): MLP | BTC_ETC
# 0.514: [period: 30min](lag: 5): Decision tree | BTC_ETC
# 0.517: [period: 30min](lag: 5): KNeighbours | BTC_ETC
#
# 0.532: [period: 30min](lag: 5): Random forest | BTC_LTC
# 0.496: [period: 30min](lag: 5): SGD | BTC_LTC
# 0.536: [period: 30min](lag: 5): Logistic regression | BTC_LTC
# 0.570: [period: 30min](lag: 5): Gradient boosting | BTC_LTC
# 0.563: [period: 30min](lag: 5): MLP | BTC_LTC
# 0.532: [period: 30min](lag: 5): Decision tree | BTC_LTC
# 0.527: [period: 30min](lag: 5): KNeighbours | BTC_LTC
#
# 0.507: [period: 30min](lag: 6): Random forest | BTC_ETC
# 0.529: [period: 30min](lag: 6): SGD | BTC_ETC
# 0.529: [period: 30min](lag: 6): Logistic regression | BTC_ETC
# 0.513: [period: 30min](lag: 6): Gradient boosting | BTC_ETC
# 0.532: [period: 30min](lag: 6): MLP | BTC_ETC
# 0.505: [period: 30min](lag: 6): Decision tree | BTC_ETC
# 0.512: [period: 30min](lag: 6): KNeighbours | BTC_ETC
#
# 0.551: [period: 30min](lag: 6): Random forest | BTC_LTC
# 0.538: [period: 30min](lag: 6): SGD | BTC_LTC
# 0.534: [period: 30min](lag: 6): Logistic regression | BTC_LTC
# 0.569: [period: 30min](lag: 6): Gradient boosting | BTC_LTC
# 0.583: [period: 30min](lag: 6): MLP | BTC_LTC
# 0.518: [period: 30min](lag: 6): Decision tree | BTC_LTC
# 0.560: [period: 30min](lag: 6): KNeighbours | BTC_LTC
#
# 0.508: [period: 30min](lag: 7): Random forest | BTC_ETC
# 0.502: [period: 30min](lag: 7): SGD | BTC_ETC
# 0.538: [period: 30min](lag: 7): Logistic regression | BTC_ETC
# 0.544: [period: 30min](lag: 7): Gradient boosting | BTC_ETC
# 0.540: [period: 30min](lag: 7): MLP | BTC_ETC
# 0.504: [period: 30min](lag: 7): Decision tree | BTC_ETC
# 0.514: [period: 30min](lag: 7): KNeighbours | BTC_ETC
#
# 0.545: [period: 30min](lag: 7): Random forest | BTC_LTC
# 0.483: [period: 30min](lag: 7): SGD | BTC_LTC
# 0.534: [period: 30min](lag: 7): Logistic regression | BTC_LTC
# 0.566: [period: 30min](lag: 7): Gradient boosting | BTC_LTC
# 0.564: [period: 30min](lag: 7): MLP | BTC_LTC
# 0.515: [period: 30min](lag: 7): Decision tree | BTC_LTC
# 0.525: [period: 30min](lag: 7): KNeighbours | BTC_LTC
#
# 0.516: [period: 30min](lag: 8): Random forest | BTC_ETC
# 0.525: [period: 30min](lag: 8): SGD | BTC_ETC
# 0.526: [period: 30min](lag: 8): Logistic regression | BTC_ETC
# 0.515: [period: 30min](lag: 8): Gradient boosting | BTC_ETC
# 0.532: [period: 30min](lag: 8): MLP | BTC_ETC
# 0.499: [period: 30min](lag: 8): Decision tree | BTC_ETC
# 0.520: [period: 30min](lag: 8): KNeighbours | BTC_ETC
#
# 0.560: [period: 30min](lag: 8): Random forest | BTC_LTC
# 0.510: [period: 30min](lag: 8): SGD | BTC_LTC
# 0.528: [period: 30min](lag: 8): Logistic regression | BTC_LTC
# 0.564: [period: 30min](lag: 8): Gradient boosting | BTC_LTC
# 0.574: [period: 30min](lag: 8): MLP | BTC_LTC
# 0.513: [period: 30min](lag: 8): Decision tree | BTC_LTC
# 0.550: [period: 30min](lag: 8): KNeighbours | BTC_LTC
#
# 0.530: [period: 30min](lag: 9): Random forest | BTC_ETC
# 0.556: [period: 30min](lag: 9): SGD | BTC_ETC
# 0.555: [period: 30min](lag: 9): Logistic regression | BTC_ETC
# 0.555: [period: 30min](lag: 9): Gradient boosting | BTC_ETC
# 0.545: [period: 30min](lag: 9): MLP | BTC_ETC
# 0.523: [period: 30min](lag: 9): Decision tree | BTC_ETC
# 0.517: [period: 30min](lag: 9): KNeighbours | BTC_ETC
#
# 0.562: [period: 30min](lag: 9): Random forest | BTC_LTC
# 0.504: [period: 30min](lag: 9): SGD | BTC_LTC
# 0.534: [period: 30min](lag: 9): Logistic regression | BTC_LTC
# 0.564: [period: 30min](lag: 9): Gradient boosting | BTC_LTC
# 0.580: [period: 30min](lag: 9): MLP | BTC_LTC
# 0.525: [period: 30min](lag: 9): Decision tree | BTC_LTC
# 0.534: [period: 30min](lag: 9): KNeighbours | BTC_LTC
#
# 0.509: [period: 30min](lag: 10): Random forest | BTC_ETC
# 0.484: [period: 30min](lag: 10): SGD | BTC_ETC
# 0.532: [period: 30min](lag: 10): Logistic regression | BTC_ETC
# 0.530: [period: 30min](lag: 10): Gradient boosting | BTC_ETC
# 0.533: [period: 30min](lag: 10): MLP | BTC_ETC
# 0.515: [period: 30min](lag: 10): Decision tree | BTC_ETC
# 0.510: [period: 30min](lag: 10): KNeighbours | BTC_ETC
#
# 0.555: [period: 30min](lag: 10): Random forest | BTC_LTC
# 0.501: [period: 30min](lag: 10): SGD | BTC_LTC
# 0.544: [period: 30min](lag: 10): Logistic regression | BTC_LTC
# 0.571: [period: 30min](lag: 10): Gradient boosting | BTC_LTC
# 0.585: [period: 30min](lag: 10): MLP | BTC_LTC
# 0.512: [period: 30min](lag: 10): Decision tree | BTC_LTC
# 0.556: [period: 30min](lag: 10): KNeighbours | BTC_LTC
#
# 0.526: [period: 30min](lag: 11): Random forest | BTC_ETC
# 0.494: [period: 30min](lag: 11): SGD | BTC_ETC
# 0.528: [period: 30min](lag: 11): Logistic regression | BTC_ETC
# 0.535: [period: 30min](lag: 11): Gradient boosting | BTC_ETC
# 0.538: [period: 30min](lag: 11): MLP | BTC_ETC
# 0.497: [period: 30min](lag: 11): Decision tree | BTC_ETC
# 0.513: [period: 30min](lag: 11): KNeighbours | BTC_ETC
#
# 0.548: [period: 30min](lag: 11): Random forest | BTC_LTC
# 0.505: [period: 30min](lag: 11): SGD | BTC_LTC
# 0.531: [period: 30min](lag: 11): Logistic regression | BTC_LTC
# 0.572: [period: 30min](lag: 11): Gradient boosting | BTC_LTC
# 0.557: [period: 30min](lag: 11): MLP | BTC_LTC
# 0.512: [period: 30min](lag: 11): Decision tree | BTC_LTC
# 0.521: [period: 30min](lag: 11): KNeighbours | BTC_LTC
#
# 0.524: [period: 30min](lag: 12): Random forest | BTC_ETC
# 0.481: [period: 30min](lag: 12): SGD | BTC_ETC
# 0.543: [period: 30min](lag: 12): Logistic regression | BTC_ETC
# 0.532: [period: 30min](lag: 12): Gradient boosting | BTC_ETC
# 0.529: [period: 30min](lag: 12): MLP | BTC_ETC
# 0.522: [period: 30min](lag: 12): Decision tree | BTC_ETC
# 0.521: [period: 30min](lag: 12): KNeighbours | BTC_ETC
#
# 0.560: [period: 30min](lag: 12): Random forest | BTC_LTC
# 0.539: [period: 30min](lag: 12): SGD | BTC_LTC
# 0.539: [period: 30min](lag: 12): Logistic regression | BTC_LTC
# 0.580: [period: 30min](lag: 12): Gradient boosting | BTC_LTC
# 0.582: [period: 30min](lag: 12): MLP | BTC_LTC
# 0.526: [period: 30min](lag: 12): Decision tree | BTC_LTC
# 0.550: [period: 30min](lag: 12): KNeighbours | BTC_LTC
#
# 0.575: [period: day](lag: 2): Random forest | BTC_ETC
# 0.658: [period: day](lag: 2): SGD | BTC_ETC
# 0.644: [period: day](lag: 2): Logistic regression | BTC_ETC
# 0.575: [period: day](lag: 2): Gradient boosting | BTC_ETC
# 0.658: [period: day](lag: 2): MLP | BTC_ETC
# 0.534: [period: day](lag: 2): Decision tree | BTC_ETC
# 0.479: [period: day](lag: 2): KNeighbours | BTC_ETC
#
# 0.534: [period: day](lag: 2): Random forest | BTC_LTC
# 0.630: [period: day](lag: 2): SGD | BTC_LTC
# 0.658: [period: day](lag: 2): Logistic regression | BTC_LTC
# 0.616: [period: day](lag: 2): Gradient boosting | BTC_LTC
# 0.644: [period: day](lag: 2): MLP | BTC_LTC
# 0.479: [period: day](lag: 2): Decision tree | BTC_LTC
# 0.507: [period: day](lag: 2): KNeighbours | BTC_LTC
#
# 0.521: [period: day](lag: 3): Random forest | BTC_ETC
# 0.521: [period: day](lag: 3): SGD | BTC_ETC
# 0.603: [period: day](lag: 3): Logistic regression | BTC_ETC
# 0.534: [period: day](lag: 3): Gradient boosting | BTC_ETC
# 0.589: [period: day](lag: 3): MLP | BTC_ETC
# 0.479: [period: day](lag: 3): Decision tree | BTC_ETC
# 0.575: [period: day](lag: 3): KNeighbours | BTC_ETC
#
# 0.630: [period: day](lag: 3): Random forest | BTC_LTC
# 0.507: [period: day](lag: 3): SGD | BTC_LTC
# 0.425: [period: day](lag: 3): Logistic regression | BTC_LTC
# 0.479: [period: day](lag: 3): Gradient boosting | BTC_LTC
# 0.438: [period: day](lag: 3): MLP | BTC_LTC
# 0.548: [period: day](lag: 3): Decision tree | BTC_LTC
# 0.479: [period: day](lag: 3): KNeighbours | BTC_LTC
#
# 0.521: [period: day](lag: 4): Random forest | BTC_ETC
# 0.534: [period: day](lag: 4): SGD | BTC_ETC
# 0.562: [period: day](lag: 4): Logistic regression | BTC_ETC
# 0.575: [period: day](lag: 4): Gradient boosting | BTC_ETC
# 0.534: [period: day](lag: 4): MLP | BTC_ETC
# 0.479: [period: day](lag: 4): Decision tree | BTC_ETC
# 0.507: [period: day](lag: 4): KNeighbours | BTC_ETC
#
# 0.466: [period: day](lag: 4): Random forest | BTC_LTC
# 0.425: [period: day](lag: 4): SGD | BTC_LTC
# 0.548: [period: day](lag: 4): Logistic regression | BTC_LTC
# 0.466: [period: day](lag: 4): Gradient boosting | BTC_LTC
# 0.562: [period: day](lag: 4): MLP | BTC_LTC
# 0.425: [period: day](lag: 4): Decision tree | BTC_LTC
# 0.534: [period: day](lag: 4): KNeighbours | BTC_LTC
#
# 0.528: [period: day](lag: 5): Random forest | BTC_ETC
# 0.403: [period: day](lag: 5): SGD | BTC_ETC
# 0.583: [period: day](lag: 5): Logistic regression | BTC_ETC
# 0.486: [period: day](lag: 5): Gradient boosting | BTC_ETC
# 0.514: [period: day](lag: 5): MLP | BTC_ETC
# 0.583: [period: day](lag: 5): Decision tree | BTC_ETC
# 0.514: [period: day](lag: 5): KNeighbours | BTC_ETC
#
# 0.500: [period: day](lag: 5): Random forest | BTC_LTC
# 0.514: [period: day](lag: 5): SGD | BTC_LTC
# 0.500: [period: day](lag: 5): Logistic regression | BTC_LTC
# 0.500: [period: day](lag: 5): Gradient boosting | BTC_LTC
# 0.472: [period: day](lag: 5): MLP | BTC_LTC
# 0.417: [period: day](lag: 5): Decision tree | BTC_LTC
# 0.611: [period: day](lag: 5): KNeighbours | BTC_LTC
#
# 0.583: [period: day](lag: 6): Random forest | BTC_ETC
# 0.389: [period: day](lag: 6): SGD | BTC_ETC
# 0.583: [period: day](lag: 6): Logistic regression | BTC_ETC
# 0.625: [period: day](lag: 6): Gradient boosting | BTC_ETC
# 0.611: [period: day](lag: 6): MLP | BTC_ETC
# 0.639: [period: day](lag: 6): Decision tree | BTC_ETC
# 0.444: [period: day](lag: 6): KNeighbours | BTC_ETC
#
# 0.444: [period: day](lag: 6): Random forest | BTC_LTC
# 0.542: [period: day](lag: 6): SGD | BTC_LTC
# 0.583: [period: day](lag: 6): Logistic regression | BTC_LTC
# 0.528: [period: day](lag: 6): Gradient boosting | BTC_LTC
# 0.583: [period: day](lag: 6): MLP | BTC_LTC
# 0.417: [period: day](lag: 6): Decision tree | BTC_LTC
# 0.569: [period: day](lag: 6): KNeighbours | BTC_LTC
#
# 0.569: [period: day](lag: 7): Random forest | BTC_ETC
# 0.514: [period: day](lag: 7): SGD | BTC_ETC
# 0.569: [period: day](lag: 7): Logistic regression | BTC_ETC
# 0.653: [period: day](lag: 7): Gradient boosting | BTC_ETC
# 0.569: [period: day](lag: 7): MLP | BTC_ETC
# 0.611: [period: day](lag: 7): Decision tree | BTC_ETC
# 0.514: [period: day](lag: 7): KNeighbours | BTC_ETC
#
# 0.458: [period: day](lag: 7): Random forest | BTC_LTC
# 0.417: [period: day](lag: 7): SGD | BTC_LTC
# 0.472: [period: day](lag: 7): Logistic regression | BTC_LTC
# 0.500: [period: day](lag: 7): Gradient boosting | BTC_LTC
# 0.431: [period: day](lag: 7): MLP | BTC_LTC
# 0.458: [period: day](lag: 7): Decision tree | BTC_LTC
# 0.611: [period: day](lag: 7): KNeighbours | BTC_LTC
#
# 0.625: [period: day](lag: 8): Random forest | BTC_ETC
# 0.403: [period: day](lag: 8): SGD | BTC_ETC
# 0.542: [period: day](lag: 8): Logistic regression | BTC_ETC
# 0.556: [period: day](lag: 8): Gradient boosting | BTC_ETC
# 0.556: [period: day](lag: 8): MLP | BTC_ETC
# 0.528: [period: day](lag: 8): Decision tree | BTC_ETC
# 0.542: [period: day](lag: 8): KNeighbours | BTC_ETC
#
# 0.569: [period: day](lag: 8): Random forest | BTC_LTC
# 0.542: [period: day](lag: 8): SGD | BTC_LTC
# 0.528: [period: day](lag: 8): Logistic regression | BTC_LTC
# 0.514: [period: day](lag: 8): Gradient boosting | BTC_LTC
# 0.528: [period: day](lag: 8): MLP | BTC_LTC
# 0.514: [period: day](lag: 8): Decision tree | BTC_LTC
# 0.556: [period: day](lag: 8): KNeighbours | BTC_LTC
#
# 0.444: [period: day](lag: 9): Random forest | BTC_ETC
# 0.569: [period: day](lag: 9): SGD | BTC_ETC
# 0.556: [period: day](lag: 9): Logistic regression | BTC_ETC
# 0.500: [period: day](lag: 9): Gradient boosting | BTC_ETC
# 0.569: [period: day](lag: 9): MLP | BTC_ETC
# 0.514: [period: day](lag: 9): Decision tree | BTC_ETC
# 0.500: [period: day](lag: 9): KNeighbours | BTC_ETC
#
# 0.458: [period: day](lag: 9): Random forest | BTC_LTC
# 0.444: [period: day](lag: 9): SGD | BTC_LTC
# 0.556: [period: day](lag: 9): Logistic regression | BTC_LTC
# 0.347: [period: day](lag: 9): Gradient boosting | BTC_LTC
# 0.514: [period: day](lag: 9): MLP | BTC_LTC
# 0.514: [period: day](lag: 9): Decision tree | BTC_LTC
# 0.431: [period: day](lag: 9): KNeighbours | BTC_LTC
#
# 0.592: [period: day](lag: 10): Random forest | BTC_ETC
# 0.535: [period: day](lag: 10): SGD | BTC_ETC
# 0.521: [period: day](lag: 10): Logistic regression | BTC_ETC
# 0.535: [period: day](lag: 10): Gradient boosting | BTC_ETC
# 0.507: [period: day](lag: 10): MLP | BTC_ETC
# 0.451: [period: day](lag: 10): Decision tree | BTC_ETC
# 0.493: [period: day](lag: 10): KNeighbours | BTC_ETC
#
# 0.507: [period: day](lag: 10): Random forest | BTC_LTC
# 0.394: [period: day](lag: 10): SGD | BTC_LTC
# 0.592: [period: day](lag: 10): Logistic regression | BTC_LTC
# 0.479: [period: day](lag: 10): Gradient boosting | BTC_LTC
# 0.592: [period: day](lag: 10): MLP | BTC_LTC
# 0.465: [period: day](lag: 10): Decision tree | BTC_LTC
# 0.521: [period: day](lag: 10): KNeighbours | BTC_LTC
#
# 0.662: [period: day](lag: 11): Random forest | BTC_ETC
# 0.648: [period: day](lag: 11): SGD | BTC_ETC
# 0.535: [period: day](lag: 11): Logistic regression | BTC_ETC
# 0.465: [period: day](lag: 11): Gradient boosting | BTC_ETC
# 0.563: [period: day](lag: 11): MLP | BTC_ETC
# 0.521: [period: day](lag: 11): Decision tree | BTC_ETC
# 0.366: [period: day](lag: 11): KNeighbours | BTC_ETC
#
# 0.577: [period: day](lag: 11): Random forest | BTC_LTC
# 0.338: [period: day](lag: 11): SGD | BTC_LTC
# 0.535: [period: day](lag: 11): Logistic regression | BTC_LTC
# 0.535: [period: day](lag: 11): Gradient boosting | BTC_LTC
# 0.563: [period: day](lag: 11): MLP | BTC_LTC
# 0.535: [period: day](lag: 11): Decision tree | BTC_LTC
# 0.521: [period: day](lag: 11): KNeighbours | BTC_LTC
#
# 0.634: [period: day](lag: 12): Random forest | BTC_ETC
# 0.535: [period: day](lag: 12): SGD | BTC_ETC
# 0.535: [period: day](lag: 12): Logistic regression | BTC_ETC
# 0.521: [period: day](lag: 12): Gradient boosting | BTC_ETC
# 0.563: [period: day](lag: 12): MLP | BTC_ETC
# 0.577: [period: day](lag: 12): Decision tree | BTC_ETC
# 0.493: [period: day](lag: 12): KNeighbours | BTC_ETC
#
# 0.493: [period: day](lag: 12): Random forest | BTC_LTC
# 0.577: [period: day](lag: 12): SGD | BTC_LTC
# 0.592: [period: day](lag: 12): Logistic regression | BTC_LTC
# 0.479: [period: day](lag: 12): Gradient boosting | BTC_LTC
# 0.577: [period: day](lag: 12): MLP | BTC_LTC
# 0.423: [period: day](lag: 12): Decision tree | BTC_LTC
# 0.521: [period: day](lag: 12): KNeighbours | BTC_LTC
