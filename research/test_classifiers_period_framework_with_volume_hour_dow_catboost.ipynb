# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier

import matplotlib.pyplot as plt

import numpy as np

from sklearn.preprocessing import StandardScaler

np.random.seed(7)

# %%
def validate_model(cls_name, model, X_train, y_train, X_test, y_test, period, pair, lag):
    info_format = '{3:.3f}: [period: {0}](lag: {1}): {2} | {4}'
    
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    print(info_format.format(period, lag, cls_name, score, pair))
    return score

def test_cls(period, pair, lag):
    df = pd.read_csv('../datasets/{}/{}.csv'.format(period, pair))
    close_lag_fields = ['close-{}'.format(n+1) for n in range(lag)]
    volume_lag_fields = ['volume-{}'.format(n+1) for n in range(lag)]
    df['datetime'] = pd.to_datetime(df['datetime'], unit='s')
    df['hour'] = df['datetime'].dt.hour
    df['dow'] = df['datetime'].dt.weekday
    df = pd.get_dummies(df, columns=['dow', 'hour'])
    dow_fields = [col for col in df if col.startswith('dow')]
    hour_fields = [col for col in df if col.startswith('hour')]
    for n in range(1, lag+1):
        df['close-' + str(n)] = df['close'] - df.shift(n)['close']
        df['volume-' + str(n)] = df['volume'] - df.shift(n)['volume']
    df['up'] = df['close'] < df.shift(-1)['close']
    df.dropna(inplace=True)
    X = df[close_lag_fields + volume_lag_fields + dow_fields + hour_fields].values
    y = df['up'].astype(int).values

    scaler = StandardScaler()

    X = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)
    
    best_score = 0.0

    model = CatBoostClassifier()
    score = validate_model('Catboost', model, X_train, y_train, X_test, y_test, period, pair, lag)
    if score > best_score:
        best_score = score
    
    print()
    return best_score

# %%
best_score = 0.0

for period in ['5min', '30min', 'day']:
    for lag in range(2, 31):
        for pair in ['BTC_ETC', 'BTC_LTC']:
            score = test_cls(period, pair, lag)
            if score > best_score:
                best_score = score
            print('Best score: {:.3f}'.format(best_score))
            print()
# Out:
# 0.573: [period: 5min](lag: 2): Catboost | BTC_ETC
#
# Best score: 0.573
#
# 0.578: [period: 5min](lag: 2): Catboost | BTC_LTC
#
# Best score: 0.578
#
# 0.571: [period: 5min](lag: 3): Catboost | BTC_ETC
#
# Best score: 0.578
#
# 0.576: [period: 5min](lag: 3): Catboost | BTC_LTC
#
# Best score: 0.578
#
# 0.573: [period: 5min](lag: 4): Catboost | BTC_ETC
#
# Best score: 0.578
#
# 0.579: [period: 5min](lag: 4): Catboost | BTC_LTC
#
# Best score: 0.579
#
# 0.576: [period: 5min](lag: 5): Catboost | BTC_ETC
#
# Best score: 0.579
#
# 0.591: [period: 5min](lag: 5): Catboost | BTC_LTC
#
# Best score: 0.591
#
# 0.574: [period: 5min](lag: 6): Catboost | BTC_ETC
#
# Best score: 0.591
#
# 0.589: [period: 5min](lag: 6): Catboost | BTC_LTC
#
# Best score: 0.591
#
# 0.574: [period: 5min](lag: 7): Catboost | BTC_ETC
#
# Best score: 0.591
#
# 0.589: [period: 5min](lag: 7): Catboost | BTC_LTC
#
# Best score: 0.591
#
# 0.576: [period: 5min](lag: 8): Catboost | BTC_ETC
#
# Best score: 0.591
#
# 0.586: [period: 5min](lag: 8): Catboost | BTC_LTC
#
# Best score: 0.591
#
# 0.575: [period: 5min](lag: 9): Catboost | BTC_ETC
#
# Best score: 0.591
#
# 0.589: [period: 5min](lag: 9): Catboost | BTC_LTC
#
# Best score: 0.591
#
# 0.573: [period: 5min](lag: 10): Catboost | BTC_ETC
#
# Best score: 0.591
#
# 0.586: [period: 5min](lag: 10): Catboost | BTC_LTC
#
# Best score: 0.591
#
# 0.570: [period: 5min](lag: 11): Catboost | BTC_ETC
#
# Best score: 0.591
#
# 0.593: [period: 5min](lag: 11): Catboost | BTC_LTC
#
# Best score: 0.593
#
# 0.576: [period: 5min](lag: 12): Catboost | BTC_ETC
#
# Best score: 0.593
#
# 0.590: [period: 5min](lag: 12): Catboost | BTC_LTC
#
# Best score: 0.593
#
# 0.580: [period: 5min](lag: 13): Catboost | BTC_ETC
#
# Best score: 0.593
#
# 0.586: [period: 5min](lag: 13): Catboost | BTC_LTC
#
# Best score: 0.593
#
# 0.578: [period: 5min](lag: 14): Catboost | BTC_ETC
#
# Best score: 0.593
#
# 0.589: [period: 5min](lag: 14): Catboost | BTC_LTC
#
# Best score: 0.593
#
# 0.580: [period: 5min](lag: 15): Catboost | BTC_ETC
#
# Best score: 0.593
#
# 0.591: [period: 5min](lag: 15): Catboost | BTC_LTC
#
# Best score: 0.593
#
# 0.579: [period: 5min](lag: 16): Catboost | BTC_ETC
#
# Best score: 0.593
#
# 0.586: [period: 5min](lag: 16): Catboost | BTC_LTC
#
# Best score: 0.593
#
# 0.581: [period: 5min](lag: 17): Catboost | BTC_ETC
#
# Best score: 0.593
#
# 0.591: [period: 5min](lag: 17): Catboost | BTC_LTC
#
# Best score: 0.593
#
# 0.577: [period: 5min](lag: 18): Catboost | BTC_ETC
#
# Best score: 0.593
#
# 0.598: [period: 5min](lag: 18): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.577: [period: 5min](lag: 19): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.589: [period: 5min](lag: 19): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.579: [period: 5min](lag: 20): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.588: [period: 5min](lag: 20): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.580: [period: 5min](lag: 21): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.592: [period: 5min](lag: 21): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.576: [period: 5min](lag: 22): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.589: [period: 5min](lag: 22): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.581: [period: 5min](lag: 23): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.594: [period: 5min](lag: 23): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.570: [period: 5min](lag: 24): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.595: [period: 5min](lag: 24): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.579: [period: 5min](lag: 25): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.589: [period: 5min](lag: 25): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.579: [period: 5min](lag: 26): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.590: [period: 5min](lag: 26): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.580: [period: 5min](lag: 27): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.589: [period: 5min](lag: 27): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.570: [period: 5min](lag: 28): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.594: [period: 5min](lag: 28): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.575: [period: 5min](lag: 29): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.591: [period: 5min](lag: 29): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.583: [period: 5min](lag: 30): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.591: [period: 5min](lag: 30): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.528: [period: 30min](lag: 2): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.561: [period: 30min](lag: 2): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.531: [period: 30min](lag: 3): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.564: [period: 30min](lag: 3): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.536: [period: 30min](lag: 4): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.561: [period: 30min](lag: 4): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.542: [period: 30min](lag: 5): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.563: [period: 30min](lag: 5): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.548: [period: 30min](lag: 6): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.562: [period: 30min](lag: 6): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.531: [period: 30min](lag: 7): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.572: [period: 30min](lag: 7): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.556: [period: 30min](lag: 8): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.565: [period: 30min](lag: 8): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.532: [period: 30min](lag: 9): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.560: [period: 30min](lag: 9): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.544: [period: 30min](lag: 10): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.578: [period: 30min](lag: 10): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.537: [period: 30min](lag: 11): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.575: [period: 30min](lag: 11): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.549: [period: 30min](lag: 12): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.573: [period: 30min](lag: 12): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.553: [period: 30min](lag: 13): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.572: [period: 30min](lag: 13): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.549: [period: 30min](lag: 14): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.560: [period: 30min](lag: 14): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.566: [period: 30min](lag: 15): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.574: [period: 30min](lag: 15): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.538: [period: 30min](lag: 16): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.579: [period: 30min](lag: 16): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.535: [period: 30min](lag: 17): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.559: [period: 30min](lag: 17): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.549: [period: 30min](lag: 18): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.577: [period: 30min](lag: 18): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.534: [period: 30min](lag: 19): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.565: [period: 30min](lag: 19): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.545: [period: 30min](lag: 20): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.572: [period: 30min](lag: 20): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.545: [period: 30min](lag: 21): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.569: [period: 30min](lag: 21): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.529: [period: 30min](lag: 22): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.576: [period: 30min](lag: 22): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.547: [period: 30min](lag: 23): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.566: [period: 30min](lag: 23): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.535: [period: 30min](lag: 24): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.575: [period: 30min](lag: 24): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.534: [period: 30min](lag: 25): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.570: [period: 30min](lag: 25): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.546: [period: 30min](lag: 26): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.559: [period: 30min](lag: 26): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.531: [period: 30min](lag: 27): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.572: [period: 30min](lag: 27): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.531: [period: 30min](lag: 28): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.582: [period: 30min](lag: 28): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.542: [period: 30min](lag: 29): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.572: [period: 30min](lag: 29): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.530: [period: 30min](lag: 30): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.562: [period: 30min](lag: 30): Catboost | BTC_LTC
#
# Best score: 0.598
# 0.548: [period: day](lag: 2): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.589: [period: day](lag: 2): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.562: [period: day](lag: 3): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.534: [period: day](lag: 3): Catboost | BTC_LTC
#
# Best score: 0.598
#
# 0.575: [period: day](lag: 4): Catboost | BTC_ETC
#
# Best score: 0.598
#
# 0.616: [period: day](lag: 4): Catboost | BTC_LTC
#
# Best score: 0.616
#
# 0.597: [period: day](lag: 5): Catboost | BTC_ETC
#
# Best score: 0.616
#
# 0.639: [period: day](lag: 5): Catboost | BTC_LTC
#
# Best score: 0.639
#
# 0.486: [period: day](lag: 6): Catboost | BTC_ETC
#
# Best score: 0.639
#
# 0.514: [period: day](lag: 6): Catboost | BTC_LTC
#
# Best score: 0.639
#
# 0.542: [period: day](lag: 7): Catboost | BTC_ETC
#
# Best score: 0.639
#
# 0.542: [period: day](lag: 7): Catboost | BTC_LTC
#
# Best score: 0.639
#
# 0.472: [period: day](lag: 8): Catboost | BTC_ETC
#
# Best score: 0.639
#
# 0.569: [period: day](lag: 8): Catboost | BTC_LTC
#
# Best score: 0.639
#
# 0.528: [period: day](lag: 9): Catboost | BTC_ETC
#
# Best score: 0.639
#
# 0.542: [period: day](lag: 9): Catboost | BTC_LTC
#
# Best score: 0.639
#
# 0.592: [period: day](lag: 10): Catboost | BTC_ETC
#
# Best score: 0.639
#
# 0.648: [period: day](lag: 10): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.549: [period: day](lag: 11): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.592: [period: day](lag: 11): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.493: [period: day](lag: 12): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.507: [period: day](lag: 12): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.563: [period: day](lag: 13): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.577: [period: day](lag: 13): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.479: [period: day](lag: 14): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.493: [period: day](lag: 14): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.543: [period: day](lag: 15): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.543: [period: day](lag: 15): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.529: [period: day](lag: 16): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.543: [period: day](lag: 16): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.414: [period: day](lag: 17): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.514: [period: day](lag: 17): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.543: [period: day](lag: 18): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.529: [period: day](lag: 18): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.429: [period: day](lag: 19): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.586: [period: day](lag: 19): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.522: [period: day](lag: 20): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.638: [period: day](lag: 20): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.493: [period: day](lag: 21): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.507: [period: day](lag: 21): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.623: [period: day](lag: 22): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.478: [period: day](lag: 22): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.565: [period: day](lag: 23): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.536: [period: day](lag: 23): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.464: [period: day](lag: 24): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.493: [period: day](lag: 24): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.544: [period: day](lag: 25): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.485: [period: day](lag: 25): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.588: [period: day](lag: 26): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.500: [period: day](lag: 26): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.529: [period: day](lag: 27): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.574: [period: day](lag: 27): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.603: [period: day](lag: 28): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.574: [period: day](lag: 28): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.529: [period: day](lag: 29): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.500: [period: day](lag: 29): Catboost | BTC_LTC
#
# Best score: 0.648
#
# 0.597: [period: day](lag: 30): Catboost | BTC_ETC
#
# Best score: 0.648
#
# 0.507: [period: day](lag: 30): Catboost | BTC_LTC
#
# Best score: 0.648
